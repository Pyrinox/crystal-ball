# %%
import pandas as pd
import glob
import csv
import os
import seaborn as sns
import matplotlib.pyplot as plt
from builtins import any

class CrystalBall:
    
    def __init__(self, list_of_csvs:list, csvname_to_colnames_list:dict, csvname_to_IDs:dict, csvname_to_nonIDs:dict, all_IDs:list, all_nonIDs:list, csvname_to_one_ID:list):
        # get list of all files in current directory that end in .csv
        self.list_of_csvs = list_of_csvs

        # create dictionary where csvname maps to colnames
        self.csvname_to_colnames_list = csvname_to_colnames_list

        # create dictionary where csvname maps to colnames that have the substring "ID"
        self.csvname_to_IDs = csvname_to_IDs

        # create dictionary where csvname maps to colnames that do not have the substring "ID"
        self.csvname_to_nonIDs = csvname_to_nonIDs

        # create list of only unique IDs
        self.all_IDs = all_IDs

        # create list of only unique nonIDs
        self.all_nonIDs = all_nonIDs
        
        # create list of all column names (IDs + nonIDs)
        self.all_colnames = list(all_IDs.union(all_nonIDs))

        # create dictionary that maps out relationship, one csvname to one ID
        self.csvname_to_one_ID = csvname_to_one_ID
    
    @classmethod
    def run(self, rel_dir):
        """ Initialize the Crystal Ball object for a given directory that contains the CSVs.

        Parameters
        ----------
        rel_dir : str
            - A string that contains the relative directory, which contains the CSVs to analyze.

        Returns
        --------
        CrystalBall
            - CrystalBall that has all class variables initialized by this run script.

        Examples
        --------
        .. code-block:: python

            relative_directory = './folder1/folder2'
            crystalBall = CrystalBall.run(relative_directory)
        """

        rel_dir = rel_dir + '/*.csv'
        list_of_csvs = sorted(glob.glob(rel_dir))
        csvname_to_colnames_list = {}
        csvname_to_IDs = {}
        csvname_to_nonIDs = {}
        all_IDs = set()
        all_nonIDs = set()
        csvname_to_one_ID = []
        for csv_name in list_of_csvs:
            with open(csv_name, "rt") as f:
                reader = csv.reader(f)
                try:
                    col_names = next(reader)
                    csvname_to_colnames_list[csv_name] = col_names
                    ids = []
                    non_ids = []
                    for col_name in col_names:
                        if 'ID' in col_name or 'Id' in col_name:
                            csvname_to_one_ID.append([os.path.split(csv_name)[1], col_name])
                            ids.append(col_name)
                        else:
                            non_ids.append(col_name)
                    csvname_to_IDs[csv_name] = ids
                    csvname_to_nonIDs[csv_name] = non_ids
                    all_IDs.update(ids)
                    all_nonIDs.update(non_ids)
                    continue
                except StopIteration:
                    continue
                except:
                    continue
        return CrystalBall(list_of_csvs, csvname_to_colnames_list, csvname_to_IDs, csvname_to_nonIDs, all_IDs, all_nonIDs, csvname_to_one_ID)

    def contains(self, keywords: list, all_colnames: list=None) -> list:    

        """ Check if keywords exist in all_colnames.
        
        - Determine whether a keyword (substring) exists in a given list of column names (strings). 
        - Note: This search is case sensitive!

        Parameters
        ----------
        keywords : list[str]
            - List of key words that the user is interested in
        all_colnames : list[str]
            - List of column names of a table, or for many tables. 
            - If no argument is provided, this function will use the column names generated when the run method was called.
        
        Returns
        -------
        list
            - Each index corresponds to a keyword. 
            - For each index, True if substring exists in list of strings, otherwise False.

        Examples
        --------
        >>> colnames = ['id', 'name', 'title']
        >>> cb.contains(['name'], colnames)
        [True]
        >>> cb.contains(['Name'], colnames)
        [False]
        >>> cb.contains(['name', 'Name'], colnames)
        [True, False]
        """
        
        if all_colnames is None:
            return [any(keyword in colname for colname in self.all_colnames) for keyword in keywords]
        else:
            return [any(keyword in colname for colname in all_colnames) for keyword in keywords]

        
    def featureSearch(self, keywords: list, all_colnames: list=None, mode: str='UNION') -> list:
        """ Find the columns that contain the keywords.

        - Find features (column names) that contain the substrings specified in keywords. 
        - Note: This search is case sensitive!

        Parameters
        ----------
        keywords : list[str]
            - List of key words that the user is interested in
        colnames : list[str]
            - List of column names of a table, or for many tables. 
            - If no argument is provided, this function will use the column names generated when the run method was called.
        
        Returns
        --------
        list[str]
            - List will contain all features (column names) that contains one/all substrings found in keywords.
            - List will be sorted in alphabetical order.

        Examples
        --------
        >>> colnames = ['id', 'name', 'nameType', 'subSpeciesName', 'title']
        >>> cb.featureSearch(['name'], colnames) 
        ['name', 'nameType']
        >>> cb.featureSearch(['Name'], colnames)
        ['subSpeciesName']
        >>> cb.featureSearch(['name', 'Name'], colnames)
        ['name', 'nameType', 'subSpeciesName']
        """

        ##implement INTERSECTION mode later
        def search(keywords, colnames):
            suggested_colnames = set()
            for colname in colnames:
                for keyword in keywords:
                    if keyword in colname:
                        suggested_colnames.add(colname)
            return sorted(list(suggested_colnames))


        if type(keywords) is not list:
            raise Exception('keywords argument expects a list')
        if mode is 'UNION':
            if all_colnames is None:
                return search(keywords, self.all_colnames)
            else:
                return search(keywords, all_colnames)
        elif mode is "INTERSECTION":
            print('to implement later')


        
    
    def tableSearch(self, keywords, csvname_to_colnames_list=None, mode='UNION'):
        """ Find the tables that contain the keywords.

        - Find tables that contain column names which have the substrings specified in keywords. 
        - Note: This search is case sensitive!

        Parameters
        ----------
        keywords : list[str]
            - List of key words that the user is interested in
        csvname_to_colnames_list : dict[str] = list
            - Dictionary that maps a string (table name) to a list of column names it contains.
            - If no argument is provided, this function will use the dictionary generated when the run method was called.
        mode : str
            - If mode is UNION, then return all tables that contain at least one keyword.
            - If mode is INTERSECTION, then return all tables that contain all the keywords.

        Returns
        --------
        list[str]
            - List will contain all tables that contain a match with keywords.
            - List will be sorted in alphabetical order.

        Examples
        --------
        >>> csvname_to_colnames_list = {'table1': ['colName1', 'colName2'], 'table2':['colName3', 'colName4']}
        >>> cb.tableSearch(['colName1'], csvname_to_colnames_list) 
        ['table1']
        >>> cb.tableSearch(['colName3'], csvname_to_colnames_list)
        ['table2']
        >>> cb.tableSearch(['colName1', 'colName2'], csvname_to_colnames_list)
        ['table1', 'table2']
        """
        
        def columnNamesContainKeyword(keyword, colname_list):
            return any(keyword in colname for colname in colname_list)
        
        if mode is 'UNION':
            if csvname_to_colnames_list is None:
                return list(filter(lambda x: x is not None, [key if False not in [True if any(keyword in colname for colname in self.csvname_to_colnames_list[key]) else False for keyword in keywords] else None for key in self.csvname_to_colnames_list]))
            else:
                return list(filter(lambda x: x is not None, [key if False not in [True if any(keyword in colname for colname in csvname_to_colnames_list[key]) else False for keyword in keywords] else None for key in csvname_to_colnames_list]))
        elif mode is 'INTERSECTION':
            csv_matches = []
            if csvname_to_colnames_list is None:
                for csvname in self.csvname_to_colnames_list:
                    keyword_checklist = []
                    for keyword in keywords:
                        keyword_checklist.append(columnNamesContainKeyword(keyword, self.csvname_to_colnames_list[csvname]))
                    if False not in keyword_checklist:
                        csv_matches.append(csvname)
                return sorted(csv_matches)
            else:
                print("implement later")

        
    def openTable(self, rel_dir, indices=[0], encoding='utf-8'):
        """ Open the csv that is referenced by the given relative directory.

        Parameters
        ----------
        rel_dir : str
            - A path to the table that is relative to where the user is running Crystal Ball.
        indices : list[int]
            - Sets the (multi)index by columns represented by their numerical integer-locations.

        Returns
        --------
        DataFrame
            - The DataFrame containing the contents of the csv.
        
        Examples
        --------
        (link juptyer notebook)
        """
        df = pd.read_csv(rel_dir, engine='python', encoding=encoding , error_bad_lines=False)
        df.set_index(list(df.columns[indices]), inplace=True)
        return df
        
        
    def subTable(self, supertable, chosen_index:list, chosen_columns:list):
        """ Create a subtable from a supertable.

        Parameters
        ----------
        supertable : DataFrame
            - Table from which to select chosen_columns from in order to form a subtable
        chosen_index : list[str]
            - The column names that will form the new (multi)index for the subtable.
        chosen_columns : list[str]
            - The column names that will form the new columns for the subtable.

        Returns
        --------
        DataFrame
            - DataFrame (the newly-formed subtable) that will have the (multi)index and columns specified in the arguments.

        Examples
        --------
        (link juptyer notebook)
        """

        combined = chosen_index.copy()
        combined.extend(chosen_columns)
        subtable = supertable[combined].set_index(primary_keys)
        return subtable
        
        
    def mergeTables(self, tables:list):
        """ Sequentially merge a list of tables that all share a common index.

        - Merge defaults to using inner joins over the index.

        Parameters
        ----------
        tables : list[DataFrame]
            - Contains a list of DataFrames that will be merged sequentially.

        Returns
        --------
        DataFrame
            - Table that results from sequentially merging the DataFrames given in the argument.

        Examples
        --------
        (link juptyer notebook)
        """
        # TO IMPLEMENT LATER: other types of joins, merging by non-index
        if len(tables) < 2:
            raise Exception("need at least two tables in order to merge")
        
        num_of_dropped_rows = 0
        max_num_of_rows = max(len(tables[0]), len(tables[1]))
        
        current_merge = tables[0].merge(tables[1], how='inner', left_index=True, right_index=True)
        
        diff = max_num_of_rows - len(current_merge)
        max_num_of_rows = len(current_merge)
        num_of_dropped_rows += diff
        
        if len(tables) - 2 > 0:
            for i in range(2, len(tables)):
                current_merge = current_merge.merge(table[i], how='inner', left_index=True, right_index=True)
                diff = max_num_of_rows - len(current_merge)
                max_num_of_rows = len(current_merge)
                num_of_dropped_rows += diff
        print('Number of Dropped Rows: ',num_of_dropped_rows)
        current_merge.index.name = tables[0].index.name
        # CHECK FOR MULTI INDEX CASE, WHETHER THE ABOVE LINE BREAKS
        return current_merge
    
    
    def analyzeRelationships(self, to_analyze:list, visualize=True):
        """ Analyze basic stats of one or more different indexes.

        By comparing boxplots, you should be able to determine which indices are related.

        Parameters
        ----------
        to_analyze : list[list[str, Series]]
            - A list of lists. The later should be of length two, in which the 0th index stores the table name and the 1st index contains a Series.
            - The Series should contain the values of the column derived from the table associated with the name stored in the 0th index.

        Returns
        --------
        DataFrame
            - Table that contains basic stats about each given Series.

        Examples
        --------
        (link juptyer notebook)
        """
        descriptions = []
        boxplot_data = []
        boxplot_xtick_labels = []
        for pair in to_analyze:
            new_name = pair[1].name + ' from ' + pair[0]
            descriptions.append(pair[1].describe().rename(new_name))
            boxplot_data.append(pair[1])
            boxplot_xtick_labels.append(new_name)
        
        if visualize:
            g = sns.boxplot(data=boxplot_data)
            g.set(
                title='Relationship Analysis',
                xlabel='Features', 
                ylabel='Numerical Values',
                xticklabels=boxplot_xtick_labels
            )
            plt.xticks(rotation=-10)

        description_table = pd.concat(descriptions, axis=1)
        return description_table

    
    def compareRelationship(self, to_analyze1, to_analyze2, visualize=False):
        """ Compare and contrast the difference between two Series.

        By comparing boxplots, you should be able to determine which indices are related.

        Parameters
        ----------
        to_analyze1 : list[str, Series]
            - A list that contains the name of the first table, and the contents of a specifc column from that table as a Series.
        to_analyze2 : list[str, Series]
            - A list that contains the name of the second table, and the contents of a specifc column from that table as a Series.

        Returns
        --------
        DataFrame
            - Table that contains basic stats about each given Series, as well as a third column that contains the difference between the stats.

        Examples
        --------
        (link juptyer notebook)
        """
        descriptions = []
        boxplot_data = []
        boxplot_xtick_labels = []
        
        new_name = to_analyze1[1].name + ' from ' + to_analyze1[0]
        description1 = to_analyze1[1].describe().rename(new_name)
        descriptions.append(description1)
        boxplot_data.append(to_analyze1[1])
        boxplot_xtick_labels.append(new_name)
        
        new_name = to_analyze2[1].name + ' from ' + to_analyze2[0]
        description2 = to_analyze2[1].describe().rename(new_name)
        descriptions.append(description2)
        boxplot_data.append(to_analyze2[1])
        boxplot_xtick_labels.append(new_name)
        
        if visualize:
            g = sns.boxplot(data=boxplot_data)
            g.set(
                title='Relationship Analysis',
                xlabel='Features', 
                ylabel='Numerical Values',
                xticklabels=boxplot_xtick_labels
            )
            plt.xticks(rotation=-10)
        
        diff_description = abs(description1 - description2)
        diff_description.name = "Difference"
        descriptions.append(diff_description)
        description_table = pd.concat(descriptions, axis=1)
        return description_table

    
    def export(self, df_to_export, write_to, export_type="CSV"):
        """ Exports contents of dataframe to relative location specified by write_to parameter.

        - Default export type is CSV

        Parameters
        ----------
        df_to_export : DataFrame
            - DataFrame whose contents will be exported into a specifed location.
        write_to : str
            - Relative location (including file) that you will write into.
        export_type : str
            - Format that contents of df_to_export will be exported as.

        Returns
        --------
        None

        Examples
        --------
        (link juptyer notebook)
        """

        if export_type is "CSV":
            df_to_export.to_csv(write_to, encoding='utf-8', index=True, index_label=df_to_export.index.name)
        else:
            print('implemnt sql format')
        
    


# to implement later
# featureSearch should return a dictionary, where key is the index and value is the name of the feature
# this makes it easier for people to select the feature they want
# search function should also have an 'is_exact' option, to make search more precise.
#   check if a lower case letter surrounds either side of the keyword, implies that it is an interjection
# create a function that let's you index into a python list with another list. useful for selecting many names at once 
# from featureSearch result

# %%
rel_dir = './tennis_demo/tennis-match-charting-project'

ball = CrystalBall.run(rel_dir)

# %%
f0 = ball.featureSearch(['name', 'Player', 'player', 'id', 'ID', 'Id'])
f0_helper = [[i, f0[i]] for i in range(len(f0))]
f0_helper
# Out:
# [[0, 'Player 1'],
#  [1, 'Player 2'],
#  [2, 'Tournament'],
#  [3, 'ad_middle'],
#  [4, 'ad_wide'],
#  [5, 'deuce_middle'],
#  [6, 'deuce_wide'],
#  [7, 'down_middle'],
#  [8, 'err_wide'],
#  [9, 'err_wide_deep'],
#  [10, 'inside_in'],
#  [11, 'inside_out'],
#  [12, 'match_id'],
#  [13, 'player'],
#  [14, 'wide']]

# %%
f0_selected = [f0[i] for i in [0]]
t0 = ball.tableSearch(f0_selected)
t0_helper = [[i, t0[i]] for i in range(len(t0))]
t0_helper
# Out:
# [[0, './tennis_demo/tennis-match-charting-project/charting-m-matches.csv'],
#  [1, './tennis_demo/tennis-match-charting-project/charting-w-matches.csv']]

# %%
df0 = ball.openTable(t0[0], encoding='latin-1')
df0
# Out:
# Skipping line 514: field larger than field limit (131072)
#                                                                  Player 1  \
# match_id
# 20180520-M-Rome_Masters-F-Rafael_Nadal-Alexande...           Rafael Nadal
# 20180519-M-Rome_Masters-SF-Rafael_Nadal-Novak_D...           Rafael Nadal
# 20180519-M-Rome_Masters-SF-Marin_Cilic-Alexande...            Marin Cilic
# 20180518-M-Rome_Masters-QF-David_Goffin-Alexand...           David Goffin
# 20180517-M-Rome_Masters-R16-Kyle_Edmund-Alexand...            Kyle Edmund
# 20180516-M-Rome_Masters-R32-Matteo_Berrettini-A...      Matteo Berrettini
# 20180513-M-Madrid_Masters-F-Dominic_Thiem-Alexa...          Dominic Thiem
# 20180512-M-Madrid_Masters-SF-Denis_Shapovalov-A...       Denis Shapovalov
# 20180511-M-Madrid_Masters-QF-Rafael_Nadal-Domin...           Rafael Nadal
# 20180511-M-Madrid_Masters-QF-John_Isner-Alexand...             John Isner
# 20180510-M-Madrid_Masters-R16-Leonardo_Mayer-Al...         Leonardo Mayer
# 20180509-M-Madrid_Masters-R32-Evgeny_Donskoy-Al...         Evgeny Donskoy
# 20180506-M-Munich-F-Philipp_Kohlschreiber-Alexa...  Philipp Kohlschreiber
# 20180506-M-Istanbul-F-Taro_Daniel-Malek_Jaziri                Taro Daniel
# 20180506-M-Estoril-F-Francis_Tiafoe-Joao_Sousa             Francis Tiafoe
# 20180505-M-Munich-SF-Maximilian_Marterer-Philip...    Maximilian Marterer
# 20180505-M-Munich-SF-Hyeon_Chung-Alexander_Zverev             Hyeon Chung
# 20180504-M-Munich-QF-Roberto_Bautista_Agut-Phil...  Roberto Bautista Agut
# 20180504-M-Munich-QF-Alexander_Zverev-Jan_Lenna...       Alexander Zverev
# 20180503-M-Munich-R16-Mischa_Zverev-Philipp_Koh...          Mischa Zverev
# 20180502-M-Munich-R16-Yannick_Hanfmann-Alexande...       Yannick Hanfmann
# 20180501-M-Munich-R32-Ivo_Karlovic-Philipp_Kohl...           Ivo Karlovic
# 20180429-M-Budapest-F-John_Millman-Marco_Cecchi...           John Millman
# 20180506-M-Estoril-F-Francis_Tiafoe-Joao_Sousa             R         R      M
# 20180505-M-Munich-SF-Maximilian_Marterer-Philip...         L         R      M
# 20180505-M-Munich-SF-Hyeon_Chung-Alexander_Zverev          R         R      M
# 20180504-M-Munich-QF-Roberto_Bautista_Agut-Phil...         R         R      M
# 20180504-M-Munich-QF-Alexander_Zverev-Jan_Lenna...         R         R      M
# 20180503-M-Munich-R16-Mischa_Zverev-Philipp_Koh...         L         R      M
# 20180502-M-Munich-R16-Yannick_Hanfmann-Alexande...         R         R      M
# 20180501-M-Munich-R32-Ivo_Karlovic-Philipp_Kohl...         R         R      M
# 20180429-M-Budapest-F-John_Millman-Marco_Cecchi...         R         R      M
# 20180429-M-Barcelona-F-Stefanos_Tsitsipas-Rafae...         R         L      M
# 20180428-M-Barcelona-SF-Stefanos_Tsitsipas-Pabl...         R         R      M
# 20180427-M-Barcelona-QF-Grigor_Dimitrov-Pablo_C...         R         R      M
# 20180426-M-Barcelona-R16-Pablo_Carreno_Busta-Ad...         R         L      M
# 20180425-M-Francavilla_Al_Mare_CH-R16-Casper_Ru...         R         R      M
# 20180425-M-Barcelona-R32-Pablo_Carreno_Busta-Be...         R         R      M
# 20180422-M-Monte_Carlo_Masters-F-Rafael_Nadal-K...         L         R      M
# ...                                                      ...       ...    ...
# 19831211-M-Australian_Open-F-Mats_Wilander-Ivan...         R         R      M
# 19830911-M-US_Open-F-Jimmy_Connors-Ivan_Lendl              L         R      M
# 19830703-M-Wimbledon-F-Chris_Lewis-John_Mcenroe            R         L      M
# 19830605-M-Roland_Garros-F-Mats_Wilander-Yannic...         R         R      M
# 19821213-M-Australian_Open-F-Steve_Denton-Johan...         R         R      M
# 19820912-M-US_Open-F-Jimmy_Connors-Ivan_Lendl              L         R      M
# 19820704-M-Wimbledon-F-John_Mcenroe-Jimmy_Connors          L         L      M
# 19820606-M-Roland_Garros-F-Guillermo_Vilas-Mats...         L         R      M
# 19820103-M-Australian_Open-F-Steve_Denton-Johan...         R         R      M
# 19810913-M-US_Open-F-John_Mcenroe-Bjorn_Borg               L         R      M
# 19810704-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg             L         R      M
# 19810607-M-Roland_Garros-F-Bjorn_Borg-Ivan_Lendl           R         R      M
# 19810104-M-Australian_Open-F-Kim_Warwick-Brian_...         R         R      M
# 19800907-M-US_Open-F-John_Mcenroe-Bjorn_Borg               L         R      M
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg             L         R      M
# 19800608-M-Roland_Garros-F-Vitas_Gerulaitis-Bjo...         R         R      M
# 19800102-M-Australian_Open-F-John_Sadri-Guiller...         R         L      M
# 19790909-M-US_Open-F-Vitas_Gerulaitis-John_Mcenroe         R         L      M
# 19790707-M-Wimbledon-F-Roscoe_Tanner-Bjorn_Borg            L         R      M
# 19790611-M-Roland_Garros-F-Bjorn_Borg-Victor_Pecci         R         R      M
# 19780910-M-US_Open-F-Bjorn_Borg-Jimmy_Connors              R         L      M
# 19780611-M-Roland_Garros-F-Bjorn_Borg-Guillermo...         R         L      M
# 19780125-M-Pepsi_Grand_Slam-SF-Brian_Gottfried-...         R         R      M
# 19770702-M-Wimbledon-SF-Vitas_Gerulaitis-Bjorn_...         R         R      M
# 19760912-M-US_Open-F-Bjorn_Borg-Jimmy_Connors              R         L      M
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor
# 19830703-M-Wimbledon-F-Chris_Lewis-John_Mcenroe        F     2:00 PM
# 19830605-M-Roland_Garros-F-Mats_Wilander-Yannic...     F    14:00:00
# 19821213-M-Australian_Open-F-Steve_Denton-Johan...     F     3:00 PM
# 19820912-M-US_Open-F-Jimmy_Connors-Ivan_Lendl          F     4:00 PM
# 19820704-M-Wimbledon-F-John_Mcenroe-Jimmy_Connors      F     2:00 PM
# 19820606-M-Roland_Garros-F-Guillermo_Vilas-Mats...     F    14:00:00
# 19820103-M-Australian_Open-F-Steve_Denton-Johan...     F         NaN
# 19810913-M-US_Open-F-John_Mcenroe-Bjorn_Borg           F         NaN
# 19810704-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg         F     2:00 PM
# 19810607-M-Roland_Garros-F-Bjorn_Borg-Ivan_Lendl       F    14:30:00
# 19810104-M-Australian_Open-F-Kim_Warwick-Brian_...     F     3:00 PM
# 19800907-M-US_Open-F-John_Mcenroe-Bjorn_Borg           F     4:00 PM
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg         F     2:00 PM
# 19800608-M-Roland_Garros-F-Vitas_Gerulaitis-Bjo...     F    14:00:00
# 19800102-M-Australian_Open-F-John_Sadri-Guiller...     F         NaN
# 19790909-M-US_Open-F-Vitas_Gerulaitis-John_Mcenroe     F         NaN
# 19790707-M-Wimbledon-F-Roscoe_Tanner-Bjorn_Borg        F       14:00
# 19790611-M-Roland_Garros-F-Bjorn_Borg-Victor_Pecci     F         NaN
# 19780910-M-US_Open-F-Bjorn_Borg-Jimmy_Connors          F         NaN
# 19780611-M-Roland_Garros-F-Bjorn_Borg-Guillermo...     F         NaN
# 19780125-M-Pepsi_Grand_Slam-SF-Brian_Gottfried-...    SF         NaN
# 19770702-M-Wimbledon-SF-Vitas_Gerulaitis-Bjorn_...    SF         NaN
# 19760912-M-US_Open-F-Bjorn_Borg-Jimmy_Connors          F         NaN
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor...    RR         NaN
# 19750705-M-Wimbledon-F-Jimmy_Connors-Arthur_Ashe       F         NaN
# 19750101-M-Australian_Open-F-Jimmy_Connors-John...     F         NaN
# 19740714-M-Bastad-F-Bjorn_Borg-Adriano_Panatta         F         NaN
# 19700322-M-New_South_Wales-F-Ken_Rosewall-Rod_L...     F         NaN
#
#                                                                  Court  \
# match_id
# 20180520-M-Rome_Masters-F-Rafael_Nadal-Alexande...            Centrale
# 20180519-M-Rome_Masters-SF-Rafael_Nadal-Novak_D...            Centrale
# 20180519-M-Rome_Masters-SF-Marin_Cilic-Alexande...            Centrale
# 20180518-M-Rome_Masters-QF-David_Goffin-Alexand...            Centrale
# 20180517-M-Rome_Masters-R16-Kyle_Edmund-Alexand...                 NaN
# 20180516-M-Rome_Masters-R32-Matteo_Berrettini-A...            Centrale
# 20180513-M-Madrid_Masters-F-Dominic_Thiem-Alexa...      Manolo Santana
# 20180512-M-Madrid_Masters-SF-Denis_Shapovalov-A...             Santana
# 20180511-M-Madrid_Masters-QF-Rafael_Nadal-Domin...      Manolo Santana
# 20180511-M-Madrid_Masters-QF-John_Isner-Alexand...             Santana
# 20180510-M-Madrid_Masters-R16-Leonardo_Mayer-Al...                 NaN
# 20180509-M-Madrid_Masters-R32-Evgeny_Donskoy-Al...             Santana
# 20180506-M-Munich-F-Philipp_Kohlschreiber-Alexa...              Centre
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor...         Isaac
# 19750705-M-Wimbledon-F-Jimmy_Connors-Arthur_Ashe    jeffsackmann
# 19750101-M-Australian_Open-F-Jimmy_Connors-John...       Palaver
# 19740714-M-Bastad-F-Bjorn_Borg-Adriano_Panatta               Edo
# 19700322-M-New_South_Wales-F-Ken_Rosewall-Rod_L...  jeffsackmann
#
# [1183 rows x 15 columns]

# %%
player_ones = list(df0['Player 1'].dropna())
player_ones.extend(list(df0['Player 2'].dropna()))
all_players = list(set(player_ones))
all_players
# Out:
# ['Lamine Ouahab',
#  'Jonas Svensson',
#  'Uladzimir Ignatik',
#  'Gastao Elias',
#  'Stefan Edberg',
#  'Richard Krajicek',
#  'Alberto Berasategui',
#  'Aldin Setkic',
#  'Cameron Norrie',
#  'Steven Diez',
#  'Guido Pella',
#  'Kenny De Schepper',
#  'Guillermo Vilas',
#  'Albert Portas',
#  'Alexander Vasilenko',
#  'Pedja Krstin',
#  'Edoardo Eremin',
#  'Agustin Calleri',
#  'Carlos Moya',
#  'Karen Khachanov',
#  'Gregoire Barrere',
#  'Mark Philippoussis',
#  'Mansour Bahrami',
#  'Tommy Paul',
#  'Roberto Carballes Baena',
#  'Andy Murray',
#  'Martin Klizan',
#  'Juan Martin del Potro',
#  'Rajeev Ram',
#  'Gleb Sakharov',
#  'Jo Wilfried Tsonga',
#  'Fabio Fognini',
#  'Dennis Novak',
#  'Benoit Paire',
#  'Miomir Kecmanovic',
#  'Emilio Gomez',
#  'Matthias Bachinger',
#  'Andrei Pavel',
#  'Denis Kudla',
#  'Daniel Gimeno Traver',
#  'Nicolas Massu',
#  'Konstantin Kravchuk',
#  'Brian Baker',
#  'Borna Coric',
#  'David Ferrer',
#  'Julien Benneteau',
#  'John Mcenroe',
#  'Ivan Ljubicic',
#  'Evgeny Donskoy',
#  'Nick Kyrgios',
#  'Andrei Medvedev',
#  'Duck Hee Lee',
#  'Pedro Cachin',
#  'Edouard Roger Vasselin',
#  'Jan Michael Gambill',
#  'Yannik Reuter',
#  'Marcus Willis',
#  'Alexandre Penaud',
#  'Marko Tepavac',
#  'David Goffin',
#  'Ilya Ivashka',
#  'N Sriram Balaji',
#  'Robin Haase',
#  'Kei Nishikori',
#  'Kevin Anderson',
#  'Todd Woodbridge',
#  'Peter Polansky',
#  'Juan Carlos Ferrero',
#  'Carlos Costa',
#  'Albert Ramos',
#  'Malek Jaziri',
#  'Felix Mantilla',
#  'Joao Domingues',
#  'Taylor Fritz',
#  'Teymuraz Gabashvili',
#  'Wayne Odesnik',
#  'Igor Andreev',
#  'Jiri Hrebec',
#  'Vladimir Ivanov',
#  'Filippo Volandri',
#  'Vitas Gerulaitis',
#  'Marcel Granollers',
#  'David Nalbandian',
#  'Marcelo Rios',
#  'Oscar Otte',
#  'Pavel Tsoy',
#  'Jonas Bjorkman',
#  'Roberto Bautista Agut',
#  'Albert Montanes',
#  'Alessandro Giannessi',
#  'Radek Stepanek',
#  'Lloyd George Muirhead Harris',
#  'Ivan Dodig',
#  'Taro Daniel',
#  'Vasek Pospisil',
#  'Michael Berrer',
#  'Gael Monfils',
#  'Filip Krajinovic',
#  'Hyeon Chung',
#  'Jonathan Eysseric',
#  'Thomas Enqvist',
#  'Federico Gaio',
#  'Andrey Kuznetsov',
#  'Miljan Zekic',
#  'Sebastien Grosjean',
#  'John Millman',
#  'Karol Beck',
#  'Malivai Washington',
#  'Ricardas Berankis',
#  'Tennys Sandgren',
#  'Federico Delbonis',
#  'Philipp Kohlschreiber',
#  'Thanasi Kokkinakis',
#  'Stefan Kozlov',
#  'Soon Woo Kwon',
#  'Fernando Verdasco',
#  'Yuichi Sugita',
#  'Mackenzie Mcdonald',
#  'Alex De Minaur',
#  'Adriano Panatta',
#  'Gaston Gaudio',
#  'Francis Tiafoe',
#  'Andrey Rublev',
#  'Dennis Novikov',
#  'Alexey Vatutin',
#  'Xavier Malisse',
#  'Andrea Gaudenzi',
#  'Jeremy Jahn',
#  'Jason Stoltenberg',
#  'Tomas Berdych',
#  'Yoshihito Nishioka',
#  'Denis Shapovalov',
#  'Jimmy Connors',
#  'Kim Warwick',
#  'Ernests Gulbis',
#  'Guillermo Coira',
#  'Yannick Noah',
#  'Victor Estrella',
#  'Bernard Tomic',
#  'Michael Chang',
#  'Bjorn Borg',
#  'Salvatore Caruso',
#  'Stefano Napolitano',
#  'Laslo Djere',
#  'Nicolas Jarry',
#  'Martin Verkerk',
#  'Aljaz Bedene',
#  'Mikael Pernfors',
#  'Sergiy Stakhovsky',
#  'Leonardo Mayer',
#  'Jiri Vesely',
#  'Greg Rusedski',
#  'Alexander Bublik',
#  'Facundo Bagnis',
#  'Peter Gojowczyk',
#  'Rod Laver',
#  'Nicolas Kiefer',
#  'Mariano Puerta',
#  'Axel Michon',
#  'Constant Lestienne',
#  'Daniil Medvedev',
#  'Davide Sanguinetti',
#  'Brad Gilbert',
#  'Roger Federer',
#  'Michael Mmoh',
#  'Jarkko Nieminen',
#  'Juan Monaco',
#  'Adam Pavlasek',
#  'Lleyton Hewitt',
#  'Reilly Opelka',
#  'Adrian Mannarino',
#  'Feliciano Lopez',
#  'Noah Rubin',
#  'Yevgeny Kafelnikov',
#  'Dominik Hrbaty',
#  'Nikoloz Basilashvili',
#  'Stefano Travaglia',
#  'Andrew Whittington',
#  'Omar Jasika',
#  'Matteo Berrettini',
#  'Novak Djokovic',
#  'Marat Safin',
#  'Marcos Baghdatis',
#  'Bjorn Fratangelo',
#  'Boris Becker',
#  'Chris Lewis',
#  'James Blake',
#  'Chris Woodruff',
#  'John Isner',
#  'Tim Smyczek',
#  'Milos Sekulic',
#  'Joris De Loore',
#  'Dominic Thiem',
#  'Ryan Harrison',
#  'Nikola Milojevic',
#  'Dustin Brown',
#  'Marc Rosset',
#  'Inigo Cervantes Huegun',
#  'Lucas Pouille',
#  'Marco Cecchinato',
#  'Nikolay Davydenko',
#  'Daniel Masur',
#  'Stephane Robert',
#  'Caio Zampieri',
#  'Jordan Thompson',
#  'Andres Gomez',
#  'Patrick Rafter',
#  'Todd Martin',
#  'Pat Cash',
#  'Stanislas Wawrinka',
#  'Brian Teacher',
#  'Ho Gi Kang',
#  'Agustin Velotti',
#  'Andreas Haider Maurer',
#  'Andreas Seppi',
#  'Michael Llodra',
#  'Casper Ruud',
#  'Florian Mayer',
#  'Marton Fucsovics',
#  'Karel Novacek',
#  'Viktor Troicki',
#  'Nicolas Lapentti',
#  'Ken Rosewall',
#  'Sergi Bruguera',
#  'Grega Zemlja',
#  'Pierre Hugues Herbert',
#  'Pablo Andujar',
#  'Nicolas Almagro',
#  'Benjamin Mitchell',
#  'Marin Cilic',
#  'Sebastian Ofner',
#  'Marc Polmans',
#  'Pablo Cuevas',
#  'Matt Reid',
#  'Gilles Simon',
#  'Alex Corretja',
#  'Karim Mohamed Maamoun',
#  'Andy Murray ',
#  'Markus Eriksson',
#  'Carlos Berlocq',
#  'Daniel Evans',
#  'Alberto Mancini',
#  'Maximilian Marterer',
#  'Tommy Haas',
#  'Elias Ymer',
#  'Joao Sousa',
#  'Guillermo Coria',
#  'Darren Cahill',
#  'Fernando Romboli',
#  'Thiago Monteiro',
#  'Johan Kriek',
#  'Thomas Johansson',
#  'Diego Sebastian Schwartzman',
#  'Blake Mott',
#  'Altug Celikbilek',
#  'Jiri Novak',
#  'Aaron Krickstein',
#  'Jan Lennard Struff',
#  'Thomaz Bellucci',
#  'Milos Raonic',
#  'Mikhail Youzhny',
#  'Richard Gasquet',
#  'Nicolas Kicker',
#  'Thomas Fabbiano',
#  'Paul Henri Mathieu',
#  'Yannick Maden',
#  'Albert Costa',
#  'Robin Soderling',
#  'Jack Sock',
#  'Sanjar Fayziev',
#  'Jeremy Chardy',
#  'Marius Copil',
#  'Guillermo Garcia Lopez',
#  'Igor Sijsling',
#  'Gustavo Kuerten',
#  'Miroslav Mecir',
#  'Juan Martin Del Potro',
#  'Marinko Matosevic',
#  'Nicolas Mahut',
#  'Jim Courier',
#  'Taylor Harry Fritz',
#  'Ivo Karlovic',
#  'Corentin Moutet',
#  'Brian Gottfried',
#  'Magnus Gustafsson',
#  'Luke Saville',
#  'Julien Boutter',
#  'Paolo Lorenzi',
#  'Zdenek Kolar',
#  'John Sadri',
#  'Mikael Torpegaard',
#  'Pete Sampras',
#  'Vaclav Safranek',
#  'Andy Roddick',
#  'Andre Agassi',
#  'Arnaud Clement',
#  'Magnus Norman',
#  'Dusan Lajovic',
#  'Jay Berger',
#  'Karol Kucera',
#  'Stefanos Tsitsipas',
#  'Rainer Schuettler',
#  'Andrei Chesnokov',
#  'Denis Istomin',
#  'Cedric Pioline',
#  'Kevin Curren',
#  'John Newcombe',
#  'Richard Kraijcek',
#  'Samuel Groth',
#  'Mardy Fish',
#  'Petr Korda',
#  'Alexander Zverev',
#  'Ivan Lendl',
#  'Janko Tipsarevic',
#  'Rafael Nadal ',
#  'Gilles Muller',
#  'Jared Donaldson',
#  'Slobodan Zivojinovic',
#  'Donald Young',
#  'Max Mirnyi',
#  'Hicham Arazi',
#  'Egor Gerasimov',
#  'Bob Bryan',
#  'Christopher Heyman',
#  'Guy Forget',
#  'Renzo Olivo',
#  'Jerzy Janowicz',
#  'Marcelo Arevalo',
#  'Tim Henman',
#  'Alejandro Falla',
#  'Dudi Sela',
#  'Gerald Melzer',
#  'Tommy Robredo',
#  'Michael Stich',
#  'Yusuke Takahashi',
#  'Damir Dzumhur',
#  'Goran Ivanisevic',
#  'Juan Aguilera',
#  'Arthur Ashe',
#  'Yen Hsun Lu',
#  'Fernando Gonzalez',
#  'Francisco Clavet',
#  'Juan Ignacio Chela',
#  'Dmitry Popko',
#  'Guillermo Canas',
#  'Steve Darcis',
#  'Fabrice Santoro',
#  'Pedro Sousa',
#  'Horacio Zeballos',
#  'Andres Artunedo',
#  'Enrique Lopez Perez',
#  'Alexandr Dolgopolov',
#  'Victor Pecci',
#  'Kyle Edmund',
#  'Steve Denton',
#  'Yannick Hanfmann',
#  'Lorenzo Giustino',
#  'Roscoe Tanner',
#  'Attila Balazs',
#  'Sam Querrey',
#  'Akira Santillan',
#  'Wayne Ferreira',
#  'Rogerio Dutra Silva',
#  'Mirza Basic',
#  'Felix Auger Aliassime',
#  'Cedrik Marcel Stebe',
#  'Grigor Dimitrov',
#  'Radu Albot',
#  'Dzmitry Zhyrmont',
#  'Thomas Muster',
#  'Mikhail Kukushkin',
#  'Somdev Devvarman',
#  'Maxime Janvier',
#  'Ernesto Escobedo',
#  'Mats Wilander',
#  'Mariano Zabaleta',
#  'Marc Sieber',
#  'Eduardo Struvay',
#  'Pablo Carreno Busta',
#  'Mischa Zverev',
#  'Jo Wilfried Tsonga ',
#  'Rafael Nadal',
#  'Henri Leconte',
#  'Illya Marchenko',
#  'Steve Johnson',
#  'Aleksandr Nedovyesov']

# %%
f0_helper
t1 = ball.tableSearch(f0[12])
t1_helper = [[i, t1[i]] for i in range(len(t1))]
t1_helper
# Out:
# [[0, './tennis_demo/tennis-match-charting-project/charting-m-matches.csv'],
#  [1, './tennis_demo/tennis-match-charting-project/charting-m-points.csv'],
#  [2,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-KeyPointsReturn.csv'],
#  [3,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-KeyPointsServe.csv'],
#  [4,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-NetPoints.csv'],
#  [5,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-Overview.csv'],
#  [6, './tennis_demo/tennis-match-charting-project/charting-m-stats-Rally.csv'],
#  [7,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-ReturnDepth.csv'],
#  [8,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-ReturnOutcomes.csv'],
#  [9,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-ServeBasics.csv'],
#  [10,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-ServeDirection.csv'],
#  [11,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-ServeInfluence.csv'],
#  [12,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-ShotDirOutcomes.csv'],
#  [13,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-ShotDirection.csv'],
#  [14,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-ShotTypes.csv'],
#  [15, './tennis_demo/tennis-match-charting-project/charting-m-stats-SnV.csv'],
#  [16,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-SvBreakSplit.csv'],
#  [17,
#   './tennis_demo/tennis-match-charting-project/charting-m-stats-SvBreakTotal.csv'],
#  [18, './tennis_demo/tennis-match-charting-project/charting-w-matches.csv'],
#  [19, './tennis_demo/tennis-match-charting-project/charting-w-points.csv'],
#  [20,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-KeyPointsReturn.csv'],
#  [21,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-KeyPointsServe.csv'],
#  [22,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-NetPoints.csv'],
#  [23,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-Overview.csv'],
#  [24,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-Rally.csv'],
#  [25,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-ReturnDepth.csv'],
#  [26,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-ReturnOutcomes.csv'],
#  [27,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-ServeBasics.csv'],
#  [28,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-ServeDirection.csv'],
#  [29,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-ServeInfluence.csv'],
#  [30,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-ShotDirOutcomes.csv'],
#  [31,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-ShotDirection.csv'],
#  [32,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-ShotTypes.csv'],
#  [33, './tennis_demo/tennis-match-charting-project/charting-w-stats-SnV.csv'],
#  [34,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-SvBreakSplit.csv'],
#  [35,
#   './tennis_demo/tennis-match-charting-project/charting-w-stats-SvBreakTotal.csv']]

# %%
df1 = ball.openTable(t1[5], encoding='latin-1')
df1
# Out:
#                                                     player    set  serve_pts  \
# match_id
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor...       1  Total         69
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor...       2  Total         63
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor...       1      1         26
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor...       2      1         18
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor...       1      2         24
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor...       2      2         26
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor...       1      3         19
# 19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bor...       2      3         19
# 19780125-M-Pepsi_Grand_Slam-SF-Brian_Gottfried-...       1  Total         55
# 19780125-M-Pepsi_Grand_Slam-SF-Brian_Gottfried-...       2  Total         49
# 19780125-M-Pepsi_Grand_Slam-SF-Brian_Gottfried-...       1      1         32
# 19780125-M-Pepsi_Grand_Slam-SF-Brian_Gottfried-...       2      1         22
# 19780125-M-Pepsi_Grand_Slam-SF-Brian_Gottfried-...       1      2         23
# 19780125-M-Pepsi_Grand_Slam-SF-Brian_Gottfried-...       2      2         27
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           1  Total        180
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           2  Total        196
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           1      1         24
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           2      1         23
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           1      2         33
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           2      2         50
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           1      3         24
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           2      3         40
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           1      4         54
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           2      4         52
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           1      5         45
# 19800705-M-Wimbledon-F-John_Mcenroe-Bjorn_Borg           2      5         31
# 19810607-M-Roland_Garros-F-Bjorn_Borg-Ivan_Lendl         1  Total         73
# 19810607-M-Roland_Garros-F-Bjorn_Borg-Ivan_Lendl         2  Total         73
# 19810607-M-Roland_Garros-F-Bjorn_Borg-Ivan_Lendl         1      1          4
# 19810607-M-Roland_Garros-F-Bjorn_Borg-Ivan_Lendl         2      1          6
# ...                                                    ...    ...        ...
# 20091114-M-Paris_Masters-SF-Novak_Djokovic-Rafa...       1      2         30
# 20091114-M-Paris_Masters-SF-Novak_Djokovic-Rafa...       2      2         20
# 20060430-M-Barcelona-F-Tommy_Robredo-Rafael_Nadal        1  Total         85
# 20060430-M-Barcelona-F-Tommy_Robredo-Rafael_Nadal        2  Total         85
# 20060430-M-Barcelona-F-Tommy_Robredo-Rafael_Nadal        1      1         28
# 20060430-M-Barcelona-F-Tommy_Robredo-Rafael_Nadal        2      1         36
# 20060430-M-Barcelona-F-Tommy_Robredo-Rafael_Nadal        1      2         29
# 20060430-M-Barcelona-F-Tommy_Robredo-Rafael_Nadal        2      2         29
# 20060430-M-Barcelona-F-Tommy_Robredo-Rafael_Nadal        1      3         28
# 20060430-M-Barcelona-F-Tommy_Robredo-Rafael_Nad